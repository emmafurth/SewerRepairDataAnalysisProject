# %%
import h3
import pandas as pd
import pyarrow
import geopandas
import h3pandas
# from h3converter import h3converter

res = 4

# %%
path = "Tree_canopy_2023_Py.gdb"
pg_tree_df = geopandas.read_file(path)
pg_tree_df.head()
# Out:
#    FEATURE_CODE  SOURCE_CODE  SHAPE_Length    SHAPE_Area  \
# 0          3201            9    522.271103   7266.812117
# 1          3201            9    803.934332  18145.941438
# 2          3201            9    718.601397  23654.258618
# 3          3201            9   1393.878883  20532.266999
# 4          3201            9    935.677704  21457.992495
#
#                                             geometry
# 0  MULTIPOLYGON (((1337595.5 453650.663, 1337597....
# 1  MULTIPOLYGON (((1330827.775 453795.99, 1330831...
# 2  MULTIPOLYGON (((1345313.745 453815.766, 134536...
# 3  MULTIPOLYGON (((1331605.685 453862.055, 133160...
# 4  MULTIPOLYGON (((1344798.263 453918.926, 134482...

# %%
pg_tree_df.geom_type.value_counts()
# Out:
# MultiPolygon    32938
# Name: count, dtype: int64

# %%
h3_tree_df = pg_tree_df.h3.polyfill(res, explode=True)
h3_tree_df.head()
# Out:
# ---------------------------------------------------------------------------
# H3FailedError                             Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 h3_tree_df = pg_tree_df.h3.polyfill(res, explode=True)
#       2 h3_tree_df.head()
#
# File ~/miniconda3/lib/python3.13/site-packages/h3pandas/util/decorator.py:68, in doc_standard.<locals>.doc_decorator.<locals>.doc_f(*args, **kwargs)
#      66 @wraps(f)
#      67 def doc_f(*args, **kwargs):
# ---> 68     return f(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/h3pandas/h3pandas.py:399, in H3Accessor.polyfill(self, resolution, explode)
#     396 def func(row):
#     397     return list(polyfill(row.geometry, resolution))
# --> 399 result = self._df.apply(func, axis=1)
#     401 if not explode:
#     402     assign_args = {COLUMN_H3_POLYFILL: result}
#
# ...
